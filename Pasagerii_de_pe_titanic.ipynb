# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexandraMihalevschi/Data_Science/blob/main/Pasagerii_de_pe_titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pasagerii de pe titanic

# %% [markdown]
# Creati un model care poate sa prezica daca o persoana va supravietui sau nu pe Titanic bazat pe caracteristicile(background-ul) care le-ar fi avut in acel context, perioada de timp, spatiu.

# %%
import pandas as pd

# %%
titanic = pd.read_csv('https://girlsgoitpublic.z6.web.core.windows.net/full.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  ... Lifeboat Body  Class
# 0            1       0.0       3  ...      NaN  NaN    3.0
# 1            2       1.0       1  ...        4  NaN    1.0
# 2            3       1.0       3  ...      14?  NaN    3.0
# 3            4       1.0       1  ...        D  NaN    1.0
# 4            5       0.0       3  ...      NaN  NaN    3.0
#
# [5 rows x 21 columns]

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
#  12  WikiId       1304 non-null   float64
#  13  Name_wiki    1304 non-null   object
#  14  Age_wiki     1302 non-null   float64
#  15  Hometown     1304 non-null   object
#  16  Boarded      1304 non-null   object
#  17  Destination  1304 non-null   object
# ...

# %%
titanic = titanic.dropna(subset=['Age'])

# %%
titanic
# Out:
#       PassengerId  Survived  Pclass  ... Lifeboat  Body  Class
# 0               1     False       3  ...      NaN   NaN    3.0
# 1               2      True       1  ...        4   NaN    1.0
# 2               3      True       3  ...      14?   NaN    3.0
# 3               4      True       1  ...        D   NaN    1.0
# 4               5     False       3  ...      NaN   NaN    3.0
# ...           ...       ...     ...  ...      ...   ...    ...
# 1300         1301      True       3  ...      NaN   NaN    3.0
# 1302         1303      True       1  ...       14   NaN    1.0
# 1303         1304      True       3  ...      NaN   3MB    3.0
# 1305         1306      True       1  ...        8   NaN    1.0
# 1306         1307      True       3  ...      NaN  32MB    3.0
#
# [1046 rows x 21 columns]

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'WikiId', 'Name_wiki',
#        'Age_wiki', 'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body',
#        'Class'],
#       dtype='object')

# %%
titanic['Survived'] = titanic['Survived'].astype('bool')
titanic['Age'] = titanic['Age'].astype('int')
titanic
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       PassengerId  Survived  Pclass  ... Lifeboat  Body  Class
# 0               1     False       3  ...      NaN   NaN    3.0
# 1               2      True       1  ...        4   NaN    1.0
# ...

# %%
#tit = titanic[['Survived', 'Pclass', 'Sex', 'Age', 'SibSp','Parch', 'Fare', 'Cabin', 'Class']]
#tit

# %%
dummies = pd.get_dummies(titanic['Sex'])
dummies
# Out:
#       female  male
# 0          0     1
# 1          1     0
# 2          1     0
# 3          1     0
# 4          0     1
# ...      ...   ...
# 1300       1     0
# 1302       1     0
# 1303       1     0
# 1305       1     0
# 1306       0     1
#
# [1046 rows x 2 columns]

# %%
tit_dummies = pd.concat([titanic, dummies], axis = 1)
tit_dummies
# Out:
#       PassengerId  Survived  Pclass  ... Class female  male
# 0               1     False       3  ...   3.0      0     1
# 1               2      True       1  ...   1.0      1     0
# 2               3      True       3  ...   3.0      1     0
# 3               4      True       1  ...   1.0      1     0
# 4               5     False       3  ...   3.0      0     1
# ...           ...       ...     ...  ...   ...    ...   ...
# 1300         1301      True       3  ...   3.0      1     0
# 1302         1303      True       1  ...   1.0      1     0
# 1303         1304      True       3  ...   3.0      1     0
# 1305         1306      True       1  ...   1.0      1     0
# 1306         1307      True       3  ...   3.0      0     1
#
# [1046 rows x 23 columns]

# %%
tit_dummies.drop(columns = ['Sex'], inplace = True)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()

# %%
parameters = ['female', 'male', 'Age']

# %%
X = tit_dummies[parameters]
y = tit_dummies['Survived']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42)

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = X.columns,
                class_names=['Survives' ,'Not survives'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('diabetes.png')
Image(graph.create_png())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
y_predict = clf.predict(X_test)

# %%
df_test_predict = pd.DataFrame({'y_test': y_test, 'y_predict' : y_predict})
df_test_predict
# Out:
#       y_test  y_predict
# 961     True       True
# 348     True       True
# 789    False       True
# 396    False       True
# 1263    True       True
# ...      ...        ...
# 771    False       True
# 529    False      False
# 1166    True       True
# 349    False       True
# 331    False       True
#
# [314 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score

# %%
accuracy_score(y_test, y_predict)
# Out:
# 0.60828025477707

# %%
precision_score(y_test, y_predict)
# Out:
# 0.6349206349206349

# %%
recall_score(y_test, y_predict)
# Out:
# 0.6896551724137931

# %%
f1_score(y_test, y_predict)
# Out:
# 0.6611570247933884

# %%
from sklearn.metrics import confusion_matrix

# %%
conf_mx = confusion_matrix(y_test, y_predict)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ax = sns.heatmap(conf_mx, annot=True, fmt="d", cbar=False)
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
ax.set_xlabel('Actual values')
ax.set_ylabel('Predicted values')
plt.yticks(rotation=0)
# Out:
# (array([0.5, 1.5]), <a list of 2 Text major ticklabel objects>)

# %%
print(len(titanic))
# Out:
# 1046

# %%
y_train_predict = clf.predict(X_train)

# %%
accuracy_score(y_train, y_train_predict)
# Out:
# 0.7363387978142076

# %%
y_predict = clf.predict(X_test)

# %%
accuracy_score(y_test, y_predict)
# Out:
# 0.60828025477707

# %%
from sklearn.model_selection import cross_val_score

# %%
acc = cross_val_score(clf, X, y, cv = 5, scoring='accuracy')
print(acc)
print()
print('Mean:', acc.mean())
print()
print('Std:', acc.std())
# Out:
# [0.71428571 0.6507177  0.65550239 0.57416268 0.53588517]
#
# Mean: 0.6261107313738893
#
# Std: 0.06337736646460451
